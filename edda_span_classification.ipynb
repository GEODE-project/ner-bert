# %% [markdown]
# # Span classification on the GeoEDdA dataset with CamemBERT
#
# This notebook shows how to use our fine-tuned CamemBERT model for span classification on the GeoEDdA dataset
#
# The model is available on HuggingFace:
# https://huggingface.co/GEODE/camembert-base-edda-span-classification
#
# It has been fine-tuned for token classification on the GeoEDdA dataset available also on HuggingFace:
# https://huggingface.co/datasets/GEODE/GeoEDdA
#
# For more details about the dataset and tagset used, see: https://github.com/GEODE-project/ner-spancat-edda

# %% [markdown]
# ## Import Pyhton libraries

# %%
from transformers import pipeline
import torch
from datasets import load_dataset
import pandas as pd
from tqdm import tqdm

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else ("cuda" if torch.cuda.is_available() else "cpu"))

# %% [markdown]
# ## Load the model

# %% [markdown]
# * Load the [GEODE/bert-base-french-cased-edda-ner](https://huggingface.co/GEODE/bert-base-french-cased-edda-ner) model pre-trained model for token classification:

# %%
pipe = pipeline("token-classification", model="GEODE/camembert-base-edda-span-classification", aggregation_strategy="simple", device=device)

# %% [markdown]
# ## Load the dataset
#
# The EDdA dataset is provided by ARTFL and is not fully available online.
# In order to test our pipeline, we can test it on the GeoEDdA dataset, which is a subset of the EDdA dataset, available on HuggingFace: https://huggingface.co/datasets/GEODE/GeoEDdA

# %% [markdown]
# * Load the [GEODE/GeoEDdA](https://huggingface.co/datasets/GEODE/GeoEDdA) dataset:

# %%
dataset = load_dataset("GEODE/GeoEDdA")

dfs = []
for key in dataset.keys():
    dfs.append(pd.DataFrame({'text':dataset[key]['text'], 'meta':dataset[key]['meta']}))
df = pd.concat(dfs, ignore_index=True)

df['head'] = df['meta'].apply(lambda x: x['head'])
df['volume'] = df['meta'].apply(lambda x: x['volume'])
df['article'] = df['meta'].apply(lambda x: x['article'])
df['paragraph'] = df['meta'].apply(lambda x: x['paragraph'])

df = df.drop(columns=['meta'])

df.head()
# Out:
#                                                 text                  head  \
# 0  ILLESCAS, (Géog.) petite ville d'Espagne, dans...              ILLESCAS
# 1  MULHAUSEN, (Géog.) ville impériale d'Allemagne...             MULHAUSEN
# 2  * ADDA, riviere de Suisse & d'Italie, qui a sa...                  ADDA
# 3  SINTRA ou CINTRA, (Géog. mod.) montagne de Por...      SINTRA ou CINTRA
# 4  * ACHSTEDE, ou AKSTEDE, s. petite Ville d'Alle...  ACHSTEDE, ou AKSTEDE
#
#    volume  article  paragraph
# 0       8     2637          1
# 1      10     3648          1
# 2       1      763          1
# 3      15     1108          1
# 4       1      603          1

# %% [markdown]
# ## Test the NER model

# %%
pipe(df.iloc[0,0])
# Out:
# [{'entity_group': 'Head',
#   'score': 0.9918164,
#   'word': 'ILLESCAS',
#   'start': 0,
#   'end': 8},
#  {'entity_group': 'Domain_mark',
#   'score': 0.82838464,
#   'word': 'Géog.',
#   'start': 11,
#   'end': 16},
#  {'entity_group': 'NC_Spatial',
#   'score': 0.9903073,
#   'word': 'petite ville',
#   'start': 18,
#   'end': 30},
#  {'entity_group': 'NP_Spatial',
#   'score': 0.9912714,
#   'word': 'Espagne',
#   'start': 33,
#   'end': 40},
#  {'entity_group': 'Relation',
#   'score': 0.987658,
#   'word': 'dans',
#   'start': 42,
#   'end': 46},
#  {'entity_group': 'NP_Spatial',
#   'score': 0.9903284,
#   'word': 'la nouvelle Castille',
#   'start': 47,
#   'end': 67},
#  {'entity_group': 'Relation',
#   'score': 0.98800606,
#   'word': 'à six lieues au sud de',
#   'start': 69,
#   'end': 91},
#  {'entity_group': 'NP_Spatial',
#   'score': 0.99158317,
#   'word': 'Madrid',
#   'start': 92,
#   'end': 98}]

# %%
def extract_entities(content, tag=None):
    return [d for d in pipe(content) if d['entity_group']==tag] if tag else pipe(content)


def extract_entities_content(content, tag):
    return ', '.join([e['word'] for e in extract_entities(content, tag)])

# %%
display(extract_entities(df.iloc[0,0], 'NP_Spatial'))
# Out:
# [{'entity_group': 'NP_Spatial',
#   'score': 0.9912714,
#   'word': 'Espagne',
#   'start': 33,
#   'end': 40},
#  {'entity_group': 'NP_Spatial',
#   'score': 0.9903284,
#   'word': 'la nouvelle Castille',
#   'start': 47,
#   'end': 67},
#  {'entity_group': 'NP_Spatial',
#   'score': 0.99158317,
#   'word': 'Madrid',
#   'start': 92,
#   'end': 98}]

# %%
display(extract_entities_content(df.iloc[0,0], 'NP_Spatial'))
# Out:
# 'Espagne, la nouvelle Castille, Madrid'

# %% [markdown]
# ## Add latlong to the dataframe

# %%
df['Latlong'] = df['text'].apply(lambda x: extract_entities_content(x, 'Latlong'))
# Out:
#                                                 text                  head  \
# 0  ILLESCAS, (Géog.) petite ville d'Espagne, dans...              ILLESCAS
# 1  MULHAUSEN, (Géog.) ville impériale d'Allemagne...             MULHAUSEN
# 2  * ADDA, riviere de Suisse & d'Italie, qui a sa...                  ADDA
# 3  SINTRA ou CINTRA, (Géog. mod.) montagne de Por...      SINTRA ou CINTRA
# 4  * ACHSTEDE, ou AKSTEDE, s. petite Ville d'Alle...  ACHSTEDE, ou AKSTEDE
#
#    volume  article  paragraph                    Latlong
# 0       8     2637          1
# 1      10     3648          1  Long. 28. 14. lat. 51. 13
# 2       1      763          1
# 3      15     1108          1
# 4       1      603          1

# %%
# count the number of rows with Latlong column not empty 
df[df['Latlong'] != ''].shape
# Out:
# (673, 6)

# %% [markdown]
# ## Get the list of all NP-Spatial (to see which ones do not have entries)

# %%
def extract_entities_asdic(content, dic={}, tags=None):
    if tags:
        for d in pipe(content):
            if d['entity_group'] in tags:
                if d['entity_group'] not in dic:
                    dic[d['entity_group']] = set()
               
                dic[d['entity_group']].add(d['word'])
    else:
        for d in pipe(content):
            if d['entity_group'] not in dic:
                dic[d['entity_group']] = set()
            
            dic[d['entity_group']].add(d['word'])
    return dic

# %%
extract_entities_asdic(df.iloc[0,0], tags=['NP_Spatial', 'NC_Spatial'])
# Out:
# {'NC_Spatial': {'petite ville'},
#  'NP_Spatial': {'Espagne', 'Madrid', 'la nouvelle Castille'}}

# %%
d = {}
for i in tqdm(range(0, 100)):
    d = extract_entities_asdic(df.iloc[i,0], d, tags=['NP_Spatial'])
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 29.82it/s]

# %%
d['NP_Spatial']
# Out:
# {"'Afrique",
#  "'Allemagne",
#  "'Eysenach",
#  'Abacoa',
#  'Aberdéen',
#  'Acambou',
#  'Adama',
#  'Afrique',
#  'Alcantara',
#  'Alger',
#  'Allemagne',
#  'Angleterre',
#  'Antilles',
#  'Argenton',
#  'Arles',
#  'Armançon',
#  'Asie',
#  'Asphastite',
#  'Augia Rheni',
#  'Aujon',
#  'Autriche',
#  'Avellino',
#  'Bahama',
#  'Bala',
#  'Barbarie',
#  'Barcelone',
#  'Baviere',
#  'Bec-Sangil',
#  'Belgrade',
#  'Benfordbridge',
#  'Bennavenna',
#  'Bennones',
#  'Besançon',
#  'Bimini',
#  'Biopio',
#  'Boristhène',
#  'Bourg',
#  'Bourgogne',
#  'Bragance',
#  'Brandebourg',
#  'Braulio',
#  'Brem',
#  'Bretagne',
#  'Brixen',
#  'Brunswic',
#  'Buchorn',
#  'Bursa',
#  'Byce',
#  'Bénevent',
#  'Calabre',
#  'Camlin',
#  'Candie',
#  "Capo d'Istria",
#  'Carcassonne',
#  'Carcinite',
#  'Cardonne',
#  'Casal',
#  'Cassel',
#  'Cerigo',
#  'Champagne',
#  'Charleroi',
#  'Chester',
#  'Chili',
#  'Châlons',
#  'Châtillon',
#  'Cianus',
#  'Cilicie',
#  'Cium',
#  'Clermont-sur-la-Dore',
#  'Cleycester',
#  'Comorin',
#  'Constantinople',
#  'Conventry',
#  'Cordonéro',
#  'Cracovie',
#  'Crémone',
#  'Cummerow',
#  'Dago',
#  'Damas',
#  'Danemark',
#  'Darby',
#  'Die Saw',
#  'Dijon',
#  'Dixmude',
#  'Démona',
#  'Erzerom',
#  'Espagne',
#  'Europe',
#  'Fanum Martis',
#  'Faro',
#  'Fez',
#  'Florentin',
#  'Folkien',
#  'Forth',
#  'Four',
#  'France',
#  'Franconie',
#  'Furnes',
#  'Gengulsinum regale',
#  'Girace',
#  'Golconde',
#  'Gomorrhe',
#  'Grenade',
#  'Gripswalde',
#  'Grisons',
#  'Grône',
#  'Guarda',
#  'Guinée',
#  'Habat',
#  'Hemona',
#  'Hend',
#  'Hesse',
#  'Hospach',
#  'Inn',
#  'Inspruck',
#  'Irlande',
#  'Italie',
#  'La Sarmatie européenne',
#  'La Save',
#  'Lago di Patria',
#  'Lampra',
#  'Lancashire',
#  'Langres',
#  'Largone',
#  'Larrons',
#  'Laubach',
#  'Lauraguais',
#  'Le Labapi',
#  'Leinster',
#  'Lichfield',
#  'Liege',
#  'Lindau',
#  'Lindum',
#  'Linterna palus',
#  'Lisbonne',
#  'Lobes',
#  'Lobrégat',
#  'Londres',
#  'Longford',
#  'Loth',
#  'Loxa',
#  'Lublin',
#  'Lucayes',
#  'Lucques',
#  'Lunoe',
#  'Lyon',
#  'Madrid',
#  'Magdebourg',
#  'Malkin',
#  'Mariannes',
#  'Marmora',
#  'Maroc',
#  'Maubeuge',
#  'Maudvessedum',
#  'Mayence',
#  'Meckelbourg',
#  'Mecklenbourg',
#  'Memneianoe',
#  'Messana',
#  'Messine',
#  'Metubaris',
#  'Minorissa',
#  'Mogol',
#  'Monaco',
#  'Montagniac',
#  'Montbrison',
#  'Monts',
#  'Moscovie',
#  'Moskow',
#  'Munich',
#  'Mâcon',
#  'Naples',
#  'Natolie',
#  'Nauportus',
#  'Nerva',
#  'Neubourg',
#  'Newcastle',
#  'Nice',
#  'Nicopolis',
#  'Nicopolis ad Istrum',
#  'Nordhausen',
#  'Nusco',
#  'OEni-pons',
#  'Olisiponente',
#  'Palus-Méotide',
#  'Paris',
#  'Pays bas',
#  'Perse',
#  'Pistoye',
#  'Pologne',
#  'Pont-Euxin',
#  "Pont-sur-l'Inn",
#  'Portugal',
#  'Portus Rutupis',
#  'Provence',
#  'Prusse',
#  'Pérou',
#  'Pô',
#  'Quangcheu',
#  'Quangtung',
#  'Quierasque',
#  'Quito',
#  'Ramanor',
#  'Ratisbonne',
#  'Ravenne',
#  'Ravieres',
#  'Rhein',
#  'Rhône',
#  'Rieti',
#  'Rimini',
#  'Rio-Pinhel',
#  'Rome',
#  'Rostock',
#  'Russie',
#  "S. John's-Town",
#  'Sabato',
#  'Sabrot',
#  'Sabus',
#  'Saccao',
#  'Salamanque',
#  'Sandomir',
#  'Santa-Severina',
#  'Sarcina',
#  'Sarcine',
#  'Sarmatiques',
#  'Sarsina',
#  'Sassina',
#  'Saus',
#  'Savio',
#  'Savoye',
#  'Savus',
#  'Saxe',
#  'Schaffouze',
#  'Segor',
#  'Segura de la sierra',
#  'Seine',
#  'Sescia',
#  'Shrewsbury',
#  'Si',
#  'Sicile',
#  'Sigestica',
#  'Sintra',
#  'Sirmium',
#  'Smolensko',
#  'Sodome',
#  'Souabe',
#  'Stafford',
#  'Suabe',
#  'Suede',
#  'Suisse',
#  'Sus',
#  'Syrie',
#  'Séboim',
#  'Taenworth',
#  'Tagliacozzo',
#  'Tagrum',
#  'Tanaïs',
#  'Tartarie',
#  'Tarudant',
#  'Taw',
#  'Tharas',
#  'Thiers',
#  'Thudinium',
#  'Thuin',
#  'Tigre',
#  'Tirol',
#  'Tra los-montes',
#  'Transylvanie',
#  'Trieste',
#  'Trébel',
#  'Tunis',
#  'Turc',
#  'Turquestan',
#  'Tyrrhénienne',
#  'Unstruth',
#  'Vennonoe',
#  'Venonoe',
#  'Vienne',
#  'Vilna',
#  'Vénédique',
#  'Wara sur la Drave',
#  'Warsovie',
#  'Warwick',
#  'Westphalie',
#  'Worcester',
#  'Ypres',
#  'Zagabria',
#  'Zaruma',
#  'bas Rhin',
#  'basse Saxe',
#  'basse-Saxe',
#  "d'Ain",
#  "d'Allemagne",
#  "d'Aquilée",
#  "d'Aranco",
#  "d'Ardagh",
#  "d'Erford",
#  "d'Onessant",
#  'grand Atlas',
#  'haut-Rhin',
#  'l',
#  "l'Abruzze ultérieure",
#  "l'Afrique",
#  "l'Agno",
#  "l'Algow",
#  "l'Amérique",
#  "l'Amérique méridionale",
#  "l'Anatolie",
#  "l'Apennin",
#  "l'Archipel",
#  "l'Ecosse méridionale",
#  "l'Ecosse septentrionale",
#  "l'Eglise",
#  "l'Estramadure",
#  "l'Euphrate",
#  "l'Hémus",
#  "l'Iatrus",
#  "l'Inde",
#  "l'Indoustan",
#  "l'Iser",
#  "l'Istrie",
#  "l'Océan",
#  "l'Océan sarmatique",
#  "l'Oder",
#  "l'ancienne Apamée",
#  "l'ancienne Sarmatie européenne",
#  "l'ancienne Sirmium",
#  'la Baviere',
#  'la Bise',
#  'la Bresse',
#  'la Bystrzna',
#  'la Calabre citérieure',
#  'la Campanie',
#  'la Castille nouvelle',
#  'la Catalogne',
#  'la Champagne',
#  'la Chine',
#  'la Coa',
#  'la Dace',
#  'la Flandre Autrichienne',
#  'la Floride',
#  'la Grande-Bretagne',
#  'la Guinée',
#  'la Livonie',
#  'la Macédoine',
#  'la Muraille',
#  'la Méditerranée',
#  'la Palestine',
#  'la Palue',
#  'la Pannonie',
#  'la Pene',
#  'la Pologne',
#  'la Poméranie',
#  'la Romagne',
#  'la Russie blanche',
#  'la Sambre',
#  'la Schuss',
#  'la Sicile',
#  'la Silésie',
#  'la Suede',
#  'la Thuringe',
#  'la Toscane',
#  'la Troade',
#  'la Turquie',
#  'la Vandalie',
#  'la Vistule',
#  'la basse Auvergne',
#  'la basse-Maesie',
#  'la haute Carniole',
#  'la nouvelle Castille',
#  'la nouvelle Zemble',
#  'la vieille Castille',
#  'le Bugey',
#  'le Clanio',
#  'le Danube',
#  'le Devonshire',
#  'le Lun',
#  'le Montferrat',
#  'le Nortjutland',
#  'le Piémont',
#  'le Pô',
#  'le Tage',
#  'le Tagrus',
#  'le Telonus',
#  'le Turgaw',
#  'le Velino',
#  'le Weser',
#  'le haut-Languedoc',
#  'le haut-Vivarez',
#  'les Alpes',
#  'les Jazyges Métanastes',
#  'les Samoyedes'}

# %%
entries = ['Afrique', 'Allemagne']

#difference between the two sets
d['NP_Spatial'].difference(entries)
# Out:
# {"'Afrique",
#  "'Allemagne",
#  "'Eysenach",
#  'Abacoa',
#  'Aberdéen',
#  'Acambou',
#  'Adama',
#  'Alcantara',
#  'Alger',
#  'Angleterre',
#  'Antilles',
#  'Argenton',
#  'Arles',
#  'Armançon',
#  'Asie',
#  'Asphastite',
#  'Augia Rheni',
#  'Aujon',
#  'Autriche',
#  'Avellino',
#  'Bahama',
#  'Bala',
#  'Barbarie',
#  'Barcelone',
#  'Baviere',
#  'Bec-Sangil',
#  'Belgrade',
#  'Benfordbridge',
#  'Bennavenna',
#  'Bennones',
#  'Besançon',
#  'Bimini',
#  'Biopio',
#  'Boristhène',
#  'Bourg',
#  'Bourgogne',
#  'Bragance',
#  'Brandebourg',
#  'Braulio',
#  'Brem',
#  'Bretagne',
#  'Brixen',
#  'Brunswic',
#  'Buchorn',
#  'Bursa',
#  'Byce',
#  'Bénevent',
#  'Calabre',
#  'Camlin',
#  'Candie',
#  "Capo d'Istria",
#  'Carcassonne',
#  'Carcinite',
#  'Cardonne',
#  'Casal',
#  'Cassel',
#  'Cerigo',
#  'Champagne',
#  'Charleroi',
#  'Chester',
#  'Chili',
#  'Châlons',
#  'Châtillon',
#  'Cianus',
#  'Cilicie',
#  'Cium',
#  'Clermont-sur-la-Dore',
#  'Cleycester',
#  'Comorin',
#  'Constantinople',
#  'Conventry',
#  'Cordonéro',
#  'Cracovie',
#  'Crémone',
#  'Cummerow',
#  'Dago',
#  'Damas',
#  'Danemark',
#  'Darby',
#  'Die Saw',
#  'Dijon',
#  'Dixmude',
#  'Démona',
#  'Erzerom',
#  'Espagne',
#  'Europe',
#  'Fanum Martis',
#  'Faro',
#  'Fez',
#  'Florentin',
#  'Folkien',
#  'Forth',
#  'Four',
#  'France',
#  'Franconie',
#  'Furnes',
#  'Gengulsinum regale',
#  'Girace',
#  'Golconde',
#  'Gomorrhe',
#  'Grenade',
#  'Gripswalde',
#  'Grisons',
#  'Grône',
#  'Guarda',
#  'Guinée',
#  'Habat',
#  'Hemona',
#  'Hend',
#  'Hesse',
#  'Hospach',
#  'Inn',
#  'Inspruck',
#  'Irlande',
#  'Italie',
#  'La Sarmatie européenne',
#  'La Save',
#  'Lago di Patria',
#  'Lampra',
#  'Lancashire',
#  'Langres',
#  'Largone',
#  'Larrons',
#  'Laubach',
#  'Lauraguais',
#  'Le Labapi',
#  'Leinster',
#  'Lichfield',
#  'Liege',
#  'Lindau',
#  'Lindum',
#  'Linterna palus',
#  'Lisbonne',
#  'Lobes',
#  'Lobrégat',
#  'Londres',
#  'Longford',
#  'Loth',
#  'Loxa',
#  'Lublin',
#  'Lucayes',
#  'Lucques',
#  'Lunoe',
#  'Lyon',
#  'Madrid',
#  'Magdebourg',
#  'Malkin',
#  'Mariannes',
#  'Marmora',
#  'Maroc',
#  'Maubeuge',
#  'Maudvessedum',
#  'Mayence',
#  'Meckelbourg',
#  'Mecklenbourg',
#  'Memneianoe',
#  'Messana',
#  'Messine',
#  'Metubaris',
#  'Minorissa',
#  'Mogol',
#  'Monaco',
#  'Montagniac',
#  'Montbrison',
#  'Monts',
#  'Moscovie',
#  'Moskow',
#  'Munich',
#  'Mâcon',
#  'Naples',
#  'Natolie',
#  'Nauportus',
#  'Nerva',
#  'Neubourg',
#  'Newcastle',
#  'Nice',
#  'Nicopolis',
#  'Nicopolis ad Istrum',
#  'Nordhausen',
#  'Nusco',
#  'OEni-pons',
#  'Olisiponente',
#  'Palus-Méotide',
#  'Paris',
#  'Pays bas',
#  'Perse',
#  'Pistoye',
#  'Pologne',
#  'Pont-Euxin',
#  "Pont-sur-l'Inn",
#  'Portugal',
#  'Portus Rutupis',
#  'Provence',
#  'Prusse',
#  'Pérou',
#  'Pô',
#  'Quangcheu',
#  'Quangtung',
#  'Quierasque',
#  'Quito',
#  'Ramanor',
#  'Ratisbonne',
#  'Ravenne',
#  'Ravieres',
#  'Rhein',
#  'Rhône',
#  'Rieti',
#  'Rimini',
#  'Rio-Pinhel',
#  'Rome',
#  'Rostock',
#  'Russie',
#  "S. John's-Town",
#  'Sabato',
#  'Sabrot',
#  'Sabus',
#  'Saccao',
#  'Salamanque',
#  'Sandomir',
#  'Santa-Severina',
#  'Sarcina',
#  'Sarcine',
#  'Sarmatiques',
#  'Sarsina',
#  'Sassina',
#  'Saus',
#  'Savio',
#  'Savoye',
#  'Savus',
#  'Saxe',
#  'Schaffouze',
#  'Segor',
#  'Segura de la sierra',
#  'Seine',
#  'Sescia',
#  'Shrewsbury',
#  'Si',
#  'Sicile',
#  'Sigestica',
#  'Sintra',
#  'Sirmium',
#  'Smolensko',
#  'Sodome',
#  'Souabe',
#  'Stafford',
#  'Suabe',
#  'Suede',
#  'Suisse',
#  'Sus',
#  'Syrie',
#  'Séboim',
#  'Taenworth',
#  'Tagliacozzo',
#  'Tagrum',
#  'Tanaïs',
#  'Tartarie',
#  'Tarudant',
#  'Taw',
#  'Tharas',
#  'Thiers',
#  'Thudinium',
#  'Thuin',
#  'Tigre',
#  'Tirol',
#  'Tra los-montes',
#  'Transylvanie',
#  'Trieste',
#  'Trébel',
#  'Tunis',
#  'Turc',
#  'Turquestan',
#  'Tyrrhénienne',
#  'Unstruth',
#  'Vennonoe',
#  'Venonoe',
#  'Vienne',
#  'Vilna',
#  'Vénédique',
#  'Wara sur la Drave',
#  'Warsovie',
#  'Warwick',
#  'Westphalie',
#  'Worcester',
#  'Ypres',
#  'Zagabria',
#  'Zaruma',
#  'bas Rhin',
#  'basse Saxe',
#  'basse-Saxe',
#  "d'Ain",
#  "d'Allemagne",
#  "d'Aquilée",
#  "d'Aranco",
#  "d'Ardagh",
#  "d'Erford",
#  "d'Onessant",
#  'grand Atlas',
#  'haut-Rhin',
#  'l',
#  "l'Abruzze ultérieure",
#  "l'Afrique",
#  "l'Agno",
#  "l'Algow",
#  "l'Amérique",
#  "l'Amérique méridionale",
#  "l'Anatolie",
#  "l'Apennin",
#  "l'Archipel",
#  "l'Ecosse méridionale",
#  "l'Ecosse septentrionale",
#  "l'Eglise",
#  "l'Estramadure",
#  "l'Euphrate",
#  "l'Hémus",
#  "l'Iatrus",
#  "l'Inde",
#  "l'Indoustan",
#  "l'Iser",
#  "l'Istrie",
#  "l'Océan",
#  "l'Océan sarmatique",
#  "l'Oder",
#  "l'ancienne Apamée",
#  "l'ancienne Sarmatie européenne",
#  "l'ancienne Sirmium",
#  'la Baviere',
#  'la Bise',
#  'la Bresse',
#  'la Bystrzna',
#  'la Calabre citérieure',
#  'la Campanie',
#  'la Castille nouvelle',
#  'la Catalogne',
#  'la Champagne',
#  'la Chine',
#  'la Coa',
#  'la Dace',
#  'la Flandre Autrichienne',
#  'la Floride',
#  'la Grande-Bretagne',
#  'la Guinée',
#  'la Livonie',
#  'la Macédoine',
#  'la Muraille',
#  'la Méditerranée',
#  'la Palestine',
#  'la Palue',
#  'la Pannonie',
#  'la Pene',
#  'la Pologne',
#  'la Poméranie',
#  'la Romagne',
#  'la Russie blanche',
#  'la Sambre',
#  'la Schuss',
#  'la Sicile',
#  'la Silésie',
#  'la Suede',
#  'la Thuringe',
#  'la Toscane',
#  'la Troade',
#  'la Turquie',
#  'la Vandalie',
#  'la Vistule',
#  'la basse Auvergne',
#  'la basse-Maesie',
#  'la haute Carniole',
#  'la nouvelle Castille',
#  'la nouvelle Zemble',
#  'la vieille Castille',
#  'le Bugey',
#  'le Clanio',
#  'le Danube',
#  'le Devonshire',
#  'le Lun',
#  'le Montferrat',
#  'le Nortjutland',
#  'le Piémont',
#  'le Pô',
#  'le Tage',
#  'le Tagrus',
#  'le Telonus',
#  'le Turgaw',
#  'le Velino',
#  'le Weser',
#  'le haut-Languedoc',
#  'le haut-Vivarez',
#  'les Alpes',
#  'les Jazyges Métanastes',
#  'les Samoyedes'}
